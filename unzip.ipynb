# %%
import zipfile

# %%
# !unzip "02.zip"
# Out:
# Archive:  02.zip
#    creating: 02/
#   inflating: __MACOSX/._02
#    creating: 02/61/
#   inflating: __MACOSX/02/._61
#    creating: 02/95/
#   inflating: __MACOSX/02/._95
#    creating: 02/92/
#   inflating: __MACOSX/02/._92
#    creating: 02/50/
#   inflating: __MACOSX/02/._50
#    creating: 02/68/
#   inflating: __MACOSX/02/._68
#    creating: 02/03/
#   inflating: __MACOSX/02/._03
#    creating: 02/04/
#   inflating: __MACOSX/02/._04
#    creating: 02/32/
#   inflating: __MACOSX/02/._32
#    creating: 02/35/
#   inflating: __MACOSX/02/._35
#    creating: 02/69/
#   inflating: __MACOSX/02/._69
#    creating: 02/94/
#   inflating: __MACOSX/02/._94
#    creating: 02/34/
#   inflating: __MACOSX/02/._34
#    creating: 02/33/
#   inflating: __MACOSX/02/._33
#    creating: 02/05/
#   inflating: __MACOSX/02/._05
#    creating: 02/18/
#   inflating: __MACOSX/02/._18
#    creating: 02/11/
#   inflating: __MACOSX/02/._11
#    creating: 02/16/
#   inflating: __MACOSX/02/._16
# ...
